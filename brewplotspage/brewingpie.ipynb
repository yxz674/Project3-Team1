# %%
import pandas as pd
import glob

# %%
files = glob.glob(r"C:\Users\Cecilia\Project3-Team1\data\united-states/*.csv")
df = pd.DataFrame()
for f in files:
    csv = pd.read_csv(f)
    df = df.append(csv)
    print(df['brewery_type'].value_counts())
# Out:
# micro       32
# planning     8
# brewpub      4
# contract     1
# Name: brewery_type, dtype: int64
# micro       61
# brewpub     18
# planning    10
# closed       4
# contract     2
# regional     1
# Name: brewery_type, dtype: int64
# micro       119
# brewpub      64
# planning     23
# contract      6
# closed        4
# regional      2
# large         2
# Name: brewery_type, dtype: int64
# micro       141
# brewpub      82
# planning     27
# contract      7
# closed        4
# regional      2
# large         2
# Name: brewery_type, dtype: int64
# micro         630
# brewpub       333
# planning       94
# contract       38
# regional       31
# large          18
# proprietor     13
# closed          4
# Name: brewery_type, dtype: int64
# micro         850
# brewpub       471
# planning      134
# contract       47
# regional       42
# large          25
# proprietor     17
# closed          4
# Name: brewery_type, dtype: int64
# micro         903
# brewpub       482
# ...
